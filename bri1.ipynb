# %%
# imports
"""
Data:

Target : 
- prediksi performa pegawai dalam 1 tahun ke depan

Interactive Data Visualization in the browser, from Python
https://github.com/bokeh/bokeh

A series of Jupyter notebooks that walk you through the fundamentals of Machine Learning and Deep Learning in python using Scikit-Learn and TensorFlow.
https://github.com/ageron/handson-ml

Python examples of popular machine learning algorithms with interactive Jupyter demos and math being explained
https://github.com/trekhleb/homemade-machine-learning

Jupyter notebooks for the code samples of the book "Deep Learning with Python"
https://github.com/fchollet/deep-learning-with-python-notebooks

DeepLearning.ai课程学习Jupyter Notebook作业
https://github.com/marsggbo/deeplearning.ai_JupyterNotebooks

Python Data Science Handbook: full text in Jupyter Notebooks
https://github.com/jakevdp/PythonDataScienceHandbook

git clone git@github.com:jakevdp/PythonDataScienceHandbook.git

https://www.kaggle.com/c/bri-data-hackathon-people-analytic/rules
bri-data-hackathon-people-analytic

"""
# import sys
# import pprint
# # print(sys.executable)
# from people import trainer

# print("imported")
import sys, os
# print(sys.executable)
import pandas as pd
import numpy as np
from patsy import dmatrices
import statsmodels.api as sm
import matplotlib.pyplot as plt
import time

path = os.path.dirname(os.path.realpath("."))
print(path)
# Out:
# /home/zam

# %%
#vars / objects inits
class Trainer:
    test = 1
    file = 'data/train.csv'
    header = []
    
    def __init__(self, file = 'data/train.csv'):
        self.file = file
        self.setHeader()
        pass

    def setHeader(self):
        header = open(self.file, "r").readline()
        self.header = header.strip().split(",")
        return self
    
    def getHeader(self):
        return list(self.header)
    
    def basicColStat(self, data):
        return {
            "avg": np.average(data),
            "min": np.min(data),
            "max": np.max(data),
#             "max": np.max(data),
        }
        
        
    def overview(self):
        file = self.file
        headers = self.getHeader()
        
        df = pd.read_csv(file, header=0)
        for h in headers:
            try:
                print(h,":",self.basicColStat(df[h]))
            except:
                print(h,": not number")
        return
#         print(df.head(10))
#         avg each columns
        
#         df = df.drop(,axis=1)
#         groups = df.groupby(['age'])
#         print(groups)
#         print(groups.count())
    
    def train(self):
        """
        train here
        - preprocess
        - feature extraction
        - algorithm
        - 
         
        """
        pass
        

def run():
    t = Trainer("/home/zam/jupyters/dummy/data/train.csv")
    t.overview()
#     t.train()

run()
# Out:
# job_level : not number
# job_duration_in_current_job_level : {'avg': 1.733251533742331, 'min': 0.0, 'max': 8.75}
# person_level : not number
# job_duration_in_current_person_level : {'avg': 1.5555437400590775, 'min': 0.0, 'max': 8.0}
# job_duration_in_current_branch : {'avg': 1.0882031356509885, 'min': 0.0, 'max': 7.5}
# Employee_type : not number
# Employee_status : not number
# gender : not number
# age : {'avg': 1987.3986821177004, 'min': 1963, 'max': 2017}
# marital_status_maried(Y/N) : not number
# number_of_dependences : {'avg': 0.746239491024767, 'min': 0, 'max': 7}
# number_of_dependences (male) : {'avg': 0.37923199272892527, 'min': 0, 'max': 4}
# number_of_dependences (female) : {'avg': 0.3669166098613951, 'min': 0, 'max': 4}
# Education_level : not number
# GPA : {'avg': nan, 'min': 0.0, 'max': 381.0}
# year_graduated : not number
# job_duration_as_permanent_worker : {'avg': nan, 'min': 1.0, 'max': 34.0}
# job_duration_from_training : {'avg': 4.546875710065894, 'min': 1, 'max': 35}
# branch_rotation : {'avg': 2.8895705521472395, 'min': 1, 'max': 22}
# job_rotation : {'avg': 2.8322653942285845, 'min': 1, 'max': 15}
# assign_of_otherposition : {'avg': 0.8187230174960236, 'min': 0, 'max': 54}
# annual leave : {'avg': 2.7941376959781867, 'min': 0, 'max': 41}
# sick_leaves : {'avg': 0.8980686207680073, 'min': 0, 'max': 132}
# Best Performance : {'avg': 0.12124517155192002, 'min': 0, 'max': 1}
# Avg_achievement_% : {'avg': nan, 'min': 0.0, 'max': 129.01}
# Last_achievement_% : {'avg': nan, 'min': 4.26, 'max': 130.0}
# Achievement_above_100%_during3quartal : {'avg': nan, 'min': 0.0, 'max': 3.0}
# achievement_target_1 : not number
# achievement_target_2 : not number
# achievement_target_3 : not number

# %%
#tester

# t = trainer.Trainer()
# pp = pprint.PrettyPrinter(indent=4)
# pp.pprint(t)

# print(t.test)
# trainer.run()
# run()
