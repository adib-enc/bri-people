# %%
# imports
"""
Data:

Machine learning memungkinkan para pembuat keputusan di departemen HR untuk memprediksikan 
performance karyawan dalam 1 tahun kedepan menggunakan data histori KPI yang dimiliki perusahaan. 
Dalam kategori People Analytics, peserta diminta untuk membangun machine learning model yang dapat 
memprediksi performance karyawan dengan akurat.


Target : 
- prediksi performa pegawai dalam 1 tahun ke depan

Interactive Data Visualization in the browser, from Python
https://github.com/bokeh/bokeh

A series of Jupyter notebooks that walk you through the fundamentals of Machine Learning and Deep Learning in python using Scikit-Learn and TensorFlow.
https://github.com/ageron/handson-ml

Python examples of popular machine learning algorithms with interactive Jupyter demos and math being explained
https://github.com/trekhleb/homemade-machine-learning

Jupyter notebooks for the code samples of the book "Deep Learning with Python"
https://github.com/fchollet/deep-learning-with-python-notebooks

DeepLearning.ai课程学习Jupyter Notebook作业
https://github.com/marsggbo/deeplearning.ai_JupyterNotebooks

Python Data Science Handbook: full text in Jupyter Notebooks
https://github.com/jakevdp/PythonDataScienceHandbook

git clone git@github.com:jakevdp/PythonDataScienceHandbook.git

https://www.kaggle.com/c/bri-data-hackathon-people-analytic/rules
bri-data-hackathon-people-analytic

https://stackoverflow.com/questions/36786722/how-to-display-full-output-in-jupyter-not-only-last-result
full-interactive enable

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
"""
# import sys
# import pprint
# # print(sys.executable)
# from people import trainer

# print("imported")
import sys, os
# print(sys.executable)
import pandas as pd
import numpy as np
from patsy import dmatrices
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns #beautiful plot
sns.set()
import time
import statistics as stt
import pprint

path = os.path.dirname(os.path.realpath("."))
print(path)

dfGlobal = None
# Out:
# /home/zam

# %%
#vars / objects inits
class BaseIO:
    file = 'data/train.csv'
    header = []
    
    def __init__(self, file = 'data/train.csv'):
        self.file = file
        self.setHeader()
        
    def setHeader(self):
        header = open(self.file, "r").readline()
        self.header = header.strip().split(",")
        return self
    
    def getHeader(self):
        return list(self.header)
    
    def getData(self):
        file = self.file
        headers = self.getHeader()
        df = pd.read_csv(file, header=0)
        
        return df
    
class Trainer:
    test = 1
    file = 'data/train.csv'
    header = []
    
    def __init__(self, file = 'data/train.csv'):
        self.file = file
        self.setHeader()
        pass

    def setHeader(self):
        header = open(self.file, "r").readline()
        self.header = header.strip().split(",")
        return self
    
    def getHeader(self):
        return list(self.header)
    
    def getStatisticMethods(self):
        statistics = stt.__all__
#         statistics.remove("StatisticsError")
        return statistics
    
    def basicColStat(self, data):
        statistics = self.getStatisticMethods()
        stats = {}
        for s in statistics:
            try:
                # call class.func with string (stt.s)
                ret = getattr(stt, s)(data)
                
                stats[s] = ret
            except:
                stats[s] = "err"

        return {
            "avg": np.average(data),
            "min": np.min(data),
            "max": np.max(data),
            "statistics": stats
#             "max": np.max(data),
        }
    
    def uniqData(self, df, h):
        uniqVals = df[h].unique()
        print("uniq",h)
#         open("columns/c"+h,"w").write(str(uniqVals))
        
    def headerNAllStat(self, df):
        headers = self.getHeader()
        pp = pprint.PrettyPrinter(indent=4)
        
        for h in headers:
            print(h,":")
            pp.pprint(self.basicColStat(df[h]))
            try:
                self.uniqData(df, h)
                pp.pprint(self.basicColStat(df[h]))
            except:
                print(h,": not number")
        
    def overview(self):
        file = self.file
        
        df = pd.read_csv(file, header=0)
#         self.headerNAllStat(df)
        ret = df
        return ret
#         print(df.head(10))
#         avg each columns
        
#         df = df.drop(,axis=1)
#         groups = df.groupby(['age'])
#         print(groups)
#         print(groups.count())
        
        
    def train(self):
        """
        train here
        - preprocess
        - feature extraction
        - algorithm
        - 
         
        """
        pass
        

def run():
    t = Trainer("/home/zam/jupyters/dummy/data/train.csv")
    ret = t.overview()
#     t.train()
    return ret

dfGlobal = run()

# %%
corr = dfGlobal.corr(method ='pearson')
corr
# Out:
#                                        job_duration_in_current_job_level  \
# job_duration_in_current_job_level                               1.000000
# job_duration_in_current_person_level                            0.838227
# job_duration_in_current_branch                                  0.178317
# age                                                            -0.674290
# number_of_dependences                                           0.414640
# number_of_dependences (male)                                    0.294118
# number_of_dependences (female)                                  0.284391
# GPA                                                             0.060593
# job_duration_as_permanent_worker                                0.750274
# job_duration_from_training                                      0.767836
# branch_rotation                                                 0.695950
# job_rotation                                                    0.629056
# ...

# %%
ret = sns.heatmap(corr, 
xticklabels=corr.columns,
yticklabels=corr.columns)

ret
# Out:
# <AxesSubplot:>

# %%
cmap = cmap=sns.diverging_palette(5, 250, as_cmap=True)

def magnify():
    return [dict(selector="th",
                 props=[("font-size", "7pt")]),
            dict(selector="td",
                 props=[('padding', "0em 0em")]),
            dict(selector="th:hover",
                 props=[("font-size", "12pt")]),
            dict(selector="tr:hover td:hover",
                 props=[('max-width', '200px'),
                        ('font-size', '12pt')])
]

corr.style.background_gradient(cmap, axis=1)\
    .set_properties(**{'max-width': '80px', 'font-size': '10pt'})\
    .set_caption("Hover to magify")\
    .set_precision(2)\
    .set_table_styles(magnify())
# Out:
# <style  type="text/css" >
#     #T_b3d92ad4_4ab9_11eb_88a0_e18facdb7bbc th {
#           font-size: 7pt;
#     }    #T_b3d92ad4_4ab9_11eb_88a0_e18facdb7bbc td {
#           padding: 0em 0em;
#     }    #T_b3d92ad4_4ab9_11eb_88a0_e18facdb7bbc th:hover {
#           font-size: 12pt;
#     }    #T_b3d92ad4_4ab9_11eb_88a0_e18facdb7bbc tr:hover td:hover {
#           max-width: 200px;
#           font-size: 12pt;
# ...

# %%
#preprocess
class Cleaner():
    def __init__(self, name, data=None):
        pass
    
    def clean(self, data, lamb1):
        ret = lamb1(data)
        return ret
        
class Preproccess():
    cols = []
    baseio = None
    output = None
    
    def __init__(self, baseio=None, cols=None):
        self.baseio = baseio
        self.cols = cols
        pass
    
    def preproccess(self):
        pp = pprint.PrettyPrinter(indent=4)
        df = self.baseio.getData()
        cols = self.cols
        
        for c in cols:
            print(c,":")
            cleaner = Cleaner(c, df[c])
            print(c)
#             pp.pprint(df[c])
            try:
                pass
#                 break
            except:
                print(h,": not number")
    
    def output(self):
        self.output = "out"
    
bio = BaseIO("/home/zam/jupyters/dummy/data/train.csv")
p = Preproccess(bio, ['achievement_target_1'])
p.preproccess()
# Out:
# achievement_target_1 :
# achievement_target_1

# %%
#tester

# t = trainer.Trainer()
# pp = pprint.PrettyPrinter(indent=4)
# pp.pprint(t)

# print(t.test)
# trainer.run()
# run()
