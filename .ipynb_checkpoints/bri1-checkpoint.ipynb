# %%
# imports
"""
Data:

Target : 
- prediksi performa pegawai dalam 1 tahun ke depan

Interactive Data Visualization in the browser, from Python
https://github.com/bokeh/bokeh

A series of Jupyter notebooks that walk you through the fundamentals of Machine Learning and Deep Learning in python using Scikit-Learn and TensorFlow.
https://github.com/ageron/handson-ml

Python examples of popular machine learning algorithms with interactive Jupyter demos and math being explained
https://github.com/trekhleb/homemade-machine-learning

Jupyter notebooks for the code samples of the book "Deep Learning with Python"
https://github.com/fchollet/deep-learning-with-python-notebooks

DeepLearning.ai课程学习Jupyter Notebook作业
https://github.com/marsggbo/deeplearning.ai_JupyterNotebooks

Python Data Science Handbook: full text in Jupyter Notebooks
https://github.com/jakevdp/PythonDataScienceHandbook

git clone git@github.com:jakevdp/PythonDataScienceHandbook.git

https://www.kaggle.com/c/bri-data-hackathon-people-analytic/rules
bri-data-hackathon-people-analytic

"""
# import sys
# import pprint
# # print(sys.executable)
# from people import trainer

# print("imported")
import sys, os
# print(sys.executable)
import pandas as pd
import numpy as np
from patsy import dmatrices
import statsmodels.api as sm
import matplotlib.pyplot as plt
import time
import statistics as stt
import pprint

path = os.path.dirname(os.path.realpath("."))
print(path)
# Out:
# /home/zam

# %%
#vars / objects inits
class Trainer:
    test = 1
    file = 'data/train.csv'
    header = []
    
    def __init__(self, file = 'data/train.csv'):
        self.file = file
        self.setHeader()
        pass

    def setHeader(self):
        header = open(self.file, "r").readline()
        self.header = header.strip().split(",")
        return self
    
    def getHeader(self):
        return list(self.header)
    
    def getStatisticMethods(self):
        statistics = stt.__all__
#         statistics.remove("StatisticsError")
        return statistics
    
    def basicColStat(self, data):
        statistics = self.getStatisticMethods()
        stats = {}
        for s in statistics:
            try:
                # call class.func with string (stt.s)
                ret = getattr(stt, s)(data)
                
                stats[s] = ret
            except:
                stats[s] = "err"

        return {
            "avg": np.average(data),
            "min": np.min(data),
            "max": np.max(data),
            "statistics": stats
#             "max": np.max(data),
        }
        
    def overview(self):
        file = self.file
        headers = self.getHeader()
        
        df = pd.read_csv(file, header=0)
        pp = pprint.PrettyPrinter(indent=4)
        for h in headers:
            print(h,":")
#             pp.pprint(self.basicColStat(df[h]))
            try:
                pp.pprint(self.basicColStat(df[h]))
#                 break
            except:
                print(h,": not number")
        return
#         print(df.head(10))
#         avg each columns
        
#         df = df.drop(,axis=1)
#         groups = df.groupby(['age'])
#         print(groups)
#         print(groups.count())
    
    def train(self):
        """
        train here
        - preprocess
        - feature extraction
        - algorithm
        - 
         
        """
        pass
        

def run():
    t = Trainer("/home/zam/jupyters/dummy/data/train.csv")
    t.overview()
#     t.train()

run()
# Out:
# job_level :
# job_level : not number
# job_duration_in_current_job_level :
# {   'avg': 1.733251533742331,
#     'max': 8.75,
#     'min': 0.0,
#     'statistics': {   'NormalDist': 'err',
#                       'fmean': 1.733251533742331,
#                       'geometric_mean': 'err',
#                       'harmonic_mean': 0,
#                       'mean': 1.7332515337423313,
#                       'median': 1.58,
#                       'median_grouped': 1.351224307417337,
#                       'median_high': 1.58,
#                       'median_low': 1.58,
#                       'mode': 1.83,
#                       'multimode': [1.83],
#                       'pstdev': 1.422103323241683,
#                       'pvariance': 2.022377861975039,
#                       'quantiles': [1.17, 1.58, 1.92],
#                       'stdev': 1.4221356375292282,
#                       'variance': 2.0224697715306643}}
# person_level :
# person_level : not number
# job_duration_in_current_person_level :
# {   'avg': 1.5555437400590775,
#     'max': 8.0,
#     'min': 0.0,
#     'statistics': {   'NormalDist': 'err',
#                       'fmean': 1.5555437400590775,
#                       'geometric_mean': 'err',
#                       'harmonic_mean': 0,
#                       'mean': 1.5555437400590775,
#                       'median': 1.5,
#                       'median_grouped': 1.9809677419354839,
#                       'median_high': 1.5,
#                       'median_low': 1.5,
#                       'mode': 1.83,
#                       'multimode': [1.83],
#                       'pstdev': 0.9545986573654676,
#                       'pvariance': 0.9112585966439534,
#                       'quantiles': [1.08, 1.5, 1.83],
#                       'stdev': 0.9546203485991495,
#                       'variance': 0.9113000099595616}}
# job_duration_in_current_branch :
# {   'avg': 1.0882031356509885,
#     'max': 7.5,
#     'min': 0.0,
#     'statistics': {   'NormalDist': 'err',
#                       'fmean': 1.0882031356509885,
#                       'geometric_mean': 'err',
#                       'harmonic_mean': 0,
#                       'mean': 1.0882031356509885,
#                       'median': 0.83,
#                       'median_grouped': 0.7275741239892183,
#                       'median_high': 0.83,
#                       'median_low': 0.83,
#                       'mode': 0.5,
#                       'multimode': [0.5],
#                       'pstdev': 0.8398627026643594,
#                       'pvariance': 0.7053693593266821,
#                       'quantiles': [0.5, 0.83, 1.5],
#                       'stdev': 0.8398817867663573,
#                       'variance': 0.7054014157418488}}
# Employee_type :
# Employee_type : not number
# Employee_status :
# Employee_status : not number
# gender :
# gender : not number
# age :
# {   'avg': 1987.3986821177004,
#     'max': 2017,
#     'min': 1963,
#     'statistics': {   'NormalDist': 'err',
#                       'fmean': 1987.3986821177004,
#                       'geometric_mean': 1987.3940717030673,
#                       'harmonic_mean': 1987.3894478985842,
#                       'mean': 1987.3986821177004,
#                       'median': 1988,
#                       'median_grouped': 1988.1224352505885,
#                       'median_high': 1988,
#                       'median_low': 1988,
#                       'mode': 1989,
#                       'multimode': [1989],
#                       'pstdev': 4.274639799042911,
#                       'pvariance': 18.272545411561616,
#                       'quantiles': [1986.0, 1988.0, 1990.0],
#                       'stdev': 4.274736931183283,
#                       'variance': 18.273375830822275}}
# marital_status_maried(Y/N) :
# marital_status_maried(Y/N) : not number
# number_of_dependences :
# {   'avg': 0.746239491024767,
#     'max': 7,
#     'min': 0,
#     'statistics': {   'NormalDist': 'err',
#                       'fmean': 0.746239491024767,
#                       'geometric_mean': 'err',
#                       'harmonic_mean': 0,
#                       'mean': 0.746239491024767,
#                       'median': 1,
#                       'median_grouped': 0.5582269503546099,
#                       'median_high': 1,
#                       'median_low': 1,
#                       'mode': 0,
#                       'multimode': [0],
#                       'pstdev': 0.8400073932515203,
#                       'pvariance': 0.7056124207172142,
#                       'quantiles': [0.0, 1.0, 1.0],
#                       'stdev': 0.8400264806413055,
#                       'variance': 0.7056444881786175}}
# number_of_dependences (male) :
# {   'avg': 0.37923199272892527,
#     'max': 4,
#     'min': 0,
#     'statistics': {   'NormalDist': 'err',
#                       'fmean': 0.37923199272892527,
#                       'geometric_mean': 'err',
#                       'harmonic_mean': 0,
#                       'mean': 0.37923199272892527,
#                       'median': 0,
#                       'median_grouped': 0.23306016390165896,
#                       'median_high': 0,
#                       'median_low': 0,
#                       'mode': 0,
#                       'multimode': [0],
#                       'pstdev': 0.6069471706955393,
#                       'pvariance': 0.3683848680153201,
#                       'quantiles': [0.0, 0.0, 1.0],
#                       'stdev': 0.6069609622851362,
#                       'variance': 0.3684016097380985}}
# number_of_dependences (female) :
# {   'avg': 0.3669166098613951,
#     'max': 4,
#     'min': 0,
#     'statistics': {   'NormalDist': 'err',
#                       'fmean': 0.3669166098613951,
#                       'geometric_mean': 'err',
#                       'harmonic_mean': 0,
#                       'mean': 0.3669166098613951,
#                       'median': 0,
#                       'median_grouped': 0.22304002102911213,
#                       'median_high': 0,
#                       'median_low': 0,
#                       'mode': 0,
#                       'multimode': [0],
#                       'pstdev': 0.5974084489657511,
#                       'pvariance': 0.3568968548956644,
#                       'quantiles': [0.0, 0.0, 1.0],
#                       'stdev': 0.5974220238080893,
#                       'variance': 0.3569130745309532}}
# Education_level :
# Education_level : not number
# GPA :
# {   'avg': nan,
#     'max': 381.0,
#     'min': 0.0,
#     'statistics': {   'NormalDist': 'err',
#                       'fmean': nan,
#                       'geometric_mean': 'err',
#                       'harmonic_mean': 0,
#                       'mean': nan,
#                       'median': nan,
#                       'median_grouped': 'err',
#                       'median_high': nan,
#                       'median_low': nan,
#                       'mode': 0.0,
#                       'multimode': [0.0],
#                       'pstdev': nan,
#                       'pvariance': nan,
#                       'quantiles': [nan, nan, 3.41],
#                       'stdev': nan,
#                       'variance': nan}}
# year_graduated :
# year_graduated : not number
# job_duration_as_permanent_worker :
# {   'avg': nan,
#     'max': 34.0,
#     'min': 1.0,
#     'statistics': {   'NormalDist': 'err',
#                       'fmean': nan,
#                       'geometric_mean': nan,
#                       'harmonic_mean': nan,
#                       'mean': nan,
#                       'median': nan,
#                       'median_grouped': 'err',
#                       'median_high': nan,
#                       'median_low': nan,
#                       'mode': 4.0,
#                       'multimode': [4.0],
#                       'pstdev': nan,
#                       'pvariance': nan,
#                       'quantiles': [26.5, nan, 5.0],
#                       'stdev': nan,
#                       'variance': nan}}
# job_duration_from_training :
# {   'avg': 4.546875710065894,
#     'max': 35,
#     'min': 1,
#     'statistics': {   'NormalDist': 'err',
#                       'fmean': 4.546875710065894,
#                       'geometric_mean': 3.246863341626788,
#                       'harmonic_mean': 2.364755861674882,
#                       'mean': 4.546875710065894,
#                       'median': 4,
#                       'median_grouped': 3.8555944055944056,
#                       'median_high': 4,
#                       'median_low': 4,
#                       'mode': 1,
#                       'multimode': [1],
#                       'pstdev': 4.5192858344835365,
#                       'pvariance': 20.423944453763553,
#                       'quantiles': [2.0, 4.0, 5.0],
#                       'stdev': 4.5193885256871695,
#                       'variance': 20.424872646112846}}
# branch_rotation :
# {   'avg': 2.8895705521472395,
#     'max': 22,
#     'min': 1,
#     'statistics': {   'NormalDist': 'err',
#                       'fmean': 2.8895705521472395,
#                       'geometric_mean': 2.345423124819116,
#                       'harmonic_mean': 1.9595822765361475,
#                       'mean': 2.8895705521472395,
#                       'median': 2,
#                       'median_grouped': 2.3800091771183847,
#                       'median_high': 2,
#                       'median_low': 2,
#                       'mode': 2,
#                       'multimode': [2],
#                       'pstdev': 2.193374340917756,
#                       'pvariance': 4.810890999396401,
#                       'quantiles': [2.0, 2.0, 3.0],
#                       'stdev': 2.1934241807064603,
#                       'variance': 4.811109636507807}}
# job_rotation :
# {   'avg': 2.8322653942285845,
#     'max': 15,
#     'min': 1,
#     'statistics': {   'NormalDist': 'err',
#                       'fmean': 2.8322653942285845,
#                       'geometric_mean': 2.418121336451385,
#                       'harmonic_mean': 2.0802040221098124,
#                       'mean': 2.8322653942285845,
#                       'median': 2,
#                       'median_grouped': 2.443253383357899,
#                       'median_high': 2,
#                       'median_low': 2,
#                       'mode': 2,
#                       'multimode': [2],
#                       'pstdev': 1.7510848595704454,
#                       'pvariance': 3.0662981854168465,
#                       'quantiles': [2.0, 2.0, 3.0],
#                       'stdev': 1.7511246492669765,
#                       'variance': 3.066437537270392}}
# assign_of_otherposition :
# {   'avg': 0.8187230174960236,
#     'max': 54,
#     'min': 0,
#     'statistics': {   'NormalDist': 'err',
#                       'fmean': 0.8187230174960236,
#                       'geometric_mean': 'err',
#                       'harmonic_mean': 0,
#                       'mean': 0.8187230174960236,
#                       'median': 0,
#                       'median_grouped': 0.16069176724914425,
#                       'median_high': 0,
#                       'median_low': 0,
#                       'mode': 0,
#                       'multimode': [0],
#                       'pstdev': 2.250137071911395,
#                       'pvariance': 5.063116842389986,
#                       'quantiles': [0.0, 0.0, 0.0],
#                       'stdev': 2.2501882015129993,
#                       'variance': 5.063346942228306}}
# annual leave :
# {   'avg': 2.7941376959781867,
#     'max': 41,
#     'min': 0,
#     'statistics': {   'NormalDist': 'err',
#                       'fmean': 2.7941376959781867,
#                       'geometric_mean': 'err',
#                       'harmonic_mean': 0,
#                       'mean': 2.7941376959781867,
#                       'median': 3,
#                       'median_grouped': 2.5539765644477685,
#                       'median_high': 3,
#                       'median_low': 3,
#                       'mode': 0,
#                       'multimode': [0],
#                       'pstdev': 2.8223589039044255,
#                       'pvariance': 7.965709782448589,
#                       'quantiles': [0.0, 3.0, 5.0],
#                       'stdev': 2.822423036035815,
#                       'variance': 7.966071794345628}}
# sick_leaves :
# {   'avg': 0.8980686207680073,
#     'max': 132,
#     'min': 0,
#     'statistics': {   'NormalDist': 'err',
#                       'fmean': 0.8980686207680073,
#                       'geometric_mean': 'err',
#                       'harmonic_mean': 0,
#                       'mean': 0.8980686207680073,
#                       'median': 0,
#                       'median_grouped': 0.2039797811760189,
#                       'median_high': 0,
#                       'median_low': 0,
#                       'mode': 0,
#                       'multimode': [0],
#                       'pstdev': 2.8484748620269236,
#                       'pvariance': 8.113809039599301,
#                       'quantiles': [0.0, 0.0, 1.0],
#                       'stdev': 2.8485395875881765,
#                       'variance': 8.114177782057018}}
# Best Performance :
# {   'avg': 0.12124517155192002,
#     'max': 1,
#     'min': 0,
#     'statistics': {   'NormalDist': 'err',
#                       'fmean': 0.12124517155192002,
#                       'geometric_mean': 'err',
#                       'harmonic_mean': 0,
#                       'mean': 0.12124517155192002,
#                       'median': 0,
#                       'median_grouped': 0.06898691627449971,
#                       'median_high': 0,
#                       'median_low': 0,
#                       'mode': 0,
#                       'multimode': [0],
#                       'pstdev': 0.32641197883543654,
#                       'pvariance': 0.10654477992726549,
#                       'quantiles': [0.0, 0.0, 0.0],
#                       'stdev': 0.32641939585666835,
#                       'variance': 0.10654962199143234}}
# Avg_achievement_% :
# {   'avg': nan,
#     'max': 129.01,
#     'min': 0.0,
#     'statistics': {   'NormalDist': 'err',
#                       'fmean': nan,
#                       'geometric_mean': 'err',
#                       'harmonic_mean': 0,
#                       'mean': nan,
#                       'median': nan,
#                       'median_grouped': 'err',
#                       'median_high': nan,
#                       'median_low': nan,
#                       'mode': 20.0,
#                       'multimode': [20.0],
#                       'pstdev': nan,
#                       'pvariance': nan,
#                       'quantiles': [nan, nan, 88.4625],
#                       'stdev': nan,
#                       'variance': nan}}
# Last_achievement_% :
# {   'avg': nan,
#     'max': 130.0,
#     'min': 4.26,
#     'statistics': {   'NormalDist': 'err',
#                       'fmean': nan,
#                       'geometric_mean': nan,
#                       'harmonic_mean': nan,
#                       'mean': nan,
#                       'median': 101.1,
#                       'median_grouped': 'err',
#                       'median_high': 101.1,
#                       'median_low': 101.1,
#                       'mode': 20.0,
#                       'multimode': [20.0],
#                       'pstdev': nan,
#                       'pvariance': nan,
#                       'quantiles': [nan, nan, nan],
#                       'stdev': nan,
#                       'variance': nan}}
# Achievement_above_100%_during3quartal :
# {   'avg': nan,
#     'max': 3.0,
#     'min': 0.0,
#     'statistics': {   'NormalDist': 'err',
#                       'fmean': nan,
#                       'geometric_mean': 'err',
#                       'harmonic_mean': 0,
#                       'mean': nan,
#                       'median': 0.0,
#                       'median_grouped': 0.19644891758450433,
#                       'median_high': 0.0,
#                       'median_low': 0.0,
#                       'mode': 0.0,
#                       'multimode': [0.0],
#                       'pstdev': nan,
#                       'pvariance': nan,
#                       'quantiles': [nan, nan, 1.0],
#                       'stdev': nan,
#                       'variance': nan}}
# achievement_target_1 :
# achievement_target_1 : not number
# achievement_target_2 :
# achievement_target_2 : not number
# achievement_target_3 :
# achievement_target_3 : not number

# %%
#tester

# t = trainer.Trainer()
# pp = pprint.PrettyPrinter(indent=4)
# pp.pprint(t)

# print(t.test)
# trainer.run()
# run()
